# %%
# Apply a function to every member of an array:
# we need to vectorize the function

def calcDivi(n, p):
    '''We can write a docstring about our function
    Here we calculate a percentage dividend based on n and p'''
    dividend = n*p
    return dividend

vec_calcDiv = np.vectorize(calcDivi)
print( vec_calcDiv(a, 0.025)  )
# Out:
# ------------------------------------------------------------------------
# NameError                              Traceback (most recent call last)
# Cell In[90], line 10
#       6     Here we calculate a percentage dividend based on n and p'''
#       7     dividend = n*p
#       8     return dividend
#       9
# ---> 10 vec_calcDiv = np.vectorize(calcDivi)
#      11 print( vec_calcDiv(a, 0.025)  )
#
# NameError: name 'np' is not defined

# %%
pip3 install numpy
pip3 install pandas
pip3 install jupyter
jupyter notebook
