# %% [markdown]
# ## Numpy and Pandas

# %%
# we need both mupy and pandas
import numpy as np
import pandas as pd

# %% [markdown]
# ## Please ensure you have a working environment with Numpy and Pandas
# ### We will be using local files so the online Python will not be suitable

# %%
# Numpy includes an array data type
a = np.array = [1,2,3,4,5] # turns out this line is wrong, and needs to be repaired
# Out:
# [3 4 5 6 7]
