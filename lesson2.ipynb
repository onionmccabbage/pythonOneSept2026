# %% [markdown]
# ## Numpy and Pandas

# %%
# we need both mupy and pandas
import numpy as np
import pandas as pd

# %%
# Numpy includes an array data type
a = np.array = [1,2,3,4,5]
a
# Out:
# [1, 2, 3, 4, 5]
